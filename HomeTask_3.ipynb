# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("C:\\Users\\79371\\Python_course\\kc_house_data.csv", encoding="latin-1")
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# #### Имя поля------------------------------Описание поля
# #### date--------------------------------------Дата продажи
# #### рriсе-------------------------------------Окончательная сумма транзакции
# #### bedrooms------------------------------Количество спален
# #### bathrooms-----------------------------Количество санузлов
# #### sqft_living-----------------------------Площадь жилых помещений (в квадратных футах)
# #### sqft lot----------------------------------Площадь земельного участка (в квадратных футах)
# #### floors------------------------------------Количество этажей
# #### waterfront------------------------------Стоит ли дом на набережной (1 : да, О: нет)
# #### view--------------------------------------Категорийная переменная вида из дома
# #### condition-------------------------------Категорийная переменная состояния дома
# #### grade------------------------------------Общий рейтинг дома по шкале оценок округа Кинг
# #### sqft_above----------------------------Площадь дома исключая подвал (в квадратных футах)
# #### sqft_basement-----------------------Площадь подвала (в квадратных футах)
# #### yr_built---------------------------------Год постройки дома
# #### yr_renovated-------------------------Год проведения последнего капремонта (если был)
# #### zipcode---------------------------------Почтовый индекс дома
# #### lat----------------------------------------Широта дома
# #### long-------------------------------------Долгота дома
# #### sqft_living15-------------------------Размер площади жилых помещений в 2015 году (в квадратных футах)

# %%
df[['price', 'sqft_lot']]
# Out:
#           price  sqft_lot
# 0      221900.0      5650
# 1      538000.0      7242
# 2      180000.0     10000
# 3      604000.0      5000
# 4      510000.0      8080
# ...         ...       ...
# 21608  360000.0      1131
# 21609  400000.0      5813
# 21610  402101.0      1350
# 21611  400000.0      2388
# 21612  325000.0      1076
#
# [21613 rows x 2 columns]

# %% [markdown]
# #### 1.1 Создать новый признак price_per_sq_lot, который будет содержать среднюю стоимость за один кв. метр общей площади

# %%
df['sqft_lot'] = pd.to_numeric(df['sqft_lot'], errors='coerce') # Преобразовать данные в столбцах в числовые
df['price'] = pd.to_numeric(df['price'], errors='coerce')
df['price_per_sq_lot'] = df['price'] / df['sqft_lot']
print('Средняя цена sqft_lot :\n', df['price_per_sq_lot'])
# Out:
# Средняя цена sqft_lot :
#  0         39.274336
# 1         74.288870
# 2         18.000000
# 3        120.800000
# 4         63.118812
#             ...
# 21608    318.302387
# 21609     68.811285
# 21610    297.852593
# 21611    167.504188
# 21612    302.044610
# Name: price_per_sq_lot, Length: 21613, dtype: float64

# %%
df['sqft_lot'] = pd.to_numeric(df['sqft_lot'], errors='coerce')
df['price'] = pd.to_numeric(df['price'], errors='coerce')
df['price_per_sq_lot'] = df['price'] / df['sqft_lot']
print('Средняя цена первых десяти домов:\n', df['price_per_sq_lot'].head(10))
# Out:
# Средняя цена первых десяти домов:
#  0     39.274336
# 1     74.288870
# 2     18.000000
# 3    120.800000
# 4     63.118812
# 5     12.018052
# 6     37.762135
# 7     30.053548
# 8     30.722892
# 9     49.237805
# Name: price_per_sq_lot, dtype: float64

# %% [markdown]
# #### 1.4 Удалите признаки date, zipcode, lat, long

# %%
df = df.drop(['date', 'zipcode', 'lat', 'long'], axis = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                21613 non-null  int64
#  1   price             21613 non-null  float64
#  2   bedrooms          21613 non-null  int64
#  3   bathrooms         21613 non-null  float64
#  4   sqft_living       21613 non-null  int64
#  5   sqft_lot          21613 non-null  int64
#  6   floors            21613 non-null  float64
#  7   waterfront        21613 non-null  int64
#  8   view              21613 non-null  int64
#  9   condition         21613 non-null  int64
#  10  grade             21613 non-null  int64
#  11  sqft_above        21613 non-null  int64
#  12  sqft_basement     21613 non-null  int64
#  13  yr_built          21613 non-null  int64
#  14  yr_renovated      21613 non-null  int64
#  15  sqft_living15     21613 non-null  int64
# ...

# %% [markdown]
# ### 2. Задача. Создайте датафрейм с клиентами:

# %%
pd.DataFrame({
'client_id': [1459, 4684, 3498, 3942, 4535, 2308, 2866, 2765, 1472, 4236, 2295,
939, 3840, 280, 20, 4332, 3475, 4213, 3113, 4809, 2134, 2242,
2068, 4929, 1384, 1589, 3317, 2260, 1727, 1764, 1611, 1474],
'house_id': [8965450190, 6823100225, 5104540330, 2131701075, 1522700060,
1189000207, 6821600300, 7137950720, 9510920050, 6131600255,
5428000070, 1788800910, 8100400160, 3123049142, 6306800010,
5083000375, 7920100025, 1951600150, 809001400, 339600110,
1622049154, 1099600250, 8563000110, 2768100205, 3995700435,
8861700030, 3303980210, 7731100066, 8146100580, 825069097,
3889100029, 9524100196]})
# Out:
#     client_id    house_id
# 0        1459  8965450190
# 1        4684  6823100225
# 2        3498  5104540330
# 3        3942  2131701075
# 4        4535  1522700060
# 5        2308  1189000207
# 6        2866  6821600300
# 7        2765  7137950720
# 8        1472  9510920050
# 9        4236  6131600255
# 10       2295  5428000070
# 11        939  1788800910
# 12       3840  8100400160
# 13        280  3123049142
# 14         20  6306800010
# 15       4332  5083000375
# 16       3475  7920100025
# 17       4213  1951600150
# 18       3113   809001400
# 19       4809   339600110
# 20       2134  1622049154
# 21       2242  1099600250
# 22       2068  8563000110
# 23       4929  2768100205
# 24       1384  3995700435
# 25       1589  8861700030
# 26       3317  3303980210
# 27       2260  7731100066
# 28       1727  8146100580
# 29       1764   825069097
# 30       1611  3889100029
# 31       1474  9524100196

# %% [markdown]
# #### 2.1 Присоедините к таблице clients данные по домам через метод join

# %%
DF1 = pd.DataFrame({
'client_id': [1459, 4684, 3498, 3942, 4535, 2308, 2866, 2765, 1472, 4236, 2295,
939, 3840, 280, 20, 4332, 3475, 4213, 3113, 4809, 2134, 2242,
2068, 4929, 1384, 1589, 3317, 2260, 1727, 1764, 1611, 1474]})

# %%
DF2 = pd.DataFrame({'house_id' : [8965450190, 6823100225, 5104540330, 2131701075, 1522700060,
1189000207, 6821600300, 7137950720, 9510920050, 6131600255,
5428000070, 1788800910, 8100400160, 3123049142, 6306800010,
5083000375, 7920100025, 1951600150, 809001400, 339600110,
1622049154, 1099600250, 8563000110, 2768100205, 3995700435,
8861700030, 3303980210, 7731100066, 8146100580, 825069097,
3889100029, 9524100196]})

# %%
DF1.join(DF2)
# Out:
#     client_id    house_id
# 0        1459  8965450190
# 1        4684  6823100225
# 2        3498  5104540330
# 3        3942  2131701075
# 4        4535  1522700060
# 5        2308  1189000207
# 6        2866  6821600300
# 7        2765  7137950720
# 8        1472  9510920050
# 9        4236  6131600255
# 10       2295  5428000070
# 11        939  1788800910
# 12       3840  8100400160
# 13        280  3123049142
# 14         20  6306800010
# 15       4332  5083000375
# 16       3475  7920100025
# 17       4213  1951600150
# 18       3113   809001400
# 19       4809   339600110
# 20       2134  1622049154
# 21       2242  1099600250
# 22       2068  8563000110
# 23       4929  2768100205
# 24       1384  3995700435
# 25       1589  8861700030
# 26       3317  3303980210
# 27       2260  7731100066
# 28       1727  8146100580
# 29       1764   825069097
# 30       1611  3889100029
# 31       1474  9524100196

# %% [markdown]
# #### 2.2 Присоедините к таблице clients данные по домам через метод merge

# %% [markdown]
# ###### Используем left_on = 'Название столбца' и right_on = 'Название столбца', у нас два разных вида данных

# %%
DF2 = pd.DataFrame({'house_id' : [8965450190, 6823100225, 5104540330, 2131701075, 1522700060,
1189000207, 6821600300, 7137950720, 9510920050, 6131600255,
5428000070, 1788800910, 8100400160, 3123049142, 6306800010,
5083000375, 7920100025, 1951600150, 809001400, 339600110,
1622049154, 1099600250, 8563000110, 2768100205, 3995700435,
8861700030, 3303980210, 7731100066, 8146100580, 825069097,
3889100029, 9524100196]})

# %%
DF1 = pd.DataFrame({
'client_id': [1459, 4684, 3498, 3942, 4535, 2308, 2866, 2765, 1472, 4236, 2295,
939, 3840, 280, 20, 4332, 3475, 4213, 3113, 4809, 2134, 2242,
2068, 4929, 1384, 1589, 3317, 2260, 1727, 1764, 1611, 1474]})

# %%
DF1.merge(DF2, left_on = 'client_id', right_on = 'house_id', how = 'outer')
# Out:
#     client_id      house_id
# 0      1459.0           NaN
# 1      4684.0           NaN
# 2      3498.0           NaN
# 3      3942.0           NaN
# 4      4535.0           NaN
# ..        ...           ...
# 59        NaN  7.731100e+09
# 60        NaN  8.146101e+09
# 61        NaN  8.250691e+08
# 62        NaN  3.889100e+09
# 63        NaN  9.524100e+09
#
# [64 rows x 2 columns]
